# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv('data/Rice Cultivation Emissions.csv')
df.head()
# Out:
#    source_id     source_name  source_type iso3_country  \
# 0   21458521  Sumatera Utara          NaN          IDN
# 1   21458521  Sumatera Utara          NaN          IDN
# 2   21458521  Sumatera Utara          NaN          IDN
# 3   21458521  Sumatera Utara          NaN          IDN
# 4   21458521  Sumatera Utara          NaN          IDN
#
#   original_inventory_sector    source_start_time      source_end_time  \
# 0          rice-cultivation  2021-01-01 00:00:00  2021-12-31 00:00:00
# 1          rice-cultivation  2021-01-01 00:00:00  2021-12-31 00:00:00
# 2          rice-cultivation  2021-01-01 00:00:00  2021-12-31 00:00:00
# 3          rice-cultivation  2021-01-01 00:00:00  2021-12-31 00:00:00
# 4          rice-cultivation  2021-01-01 00:00:00  2021-12-31 00:00:00
#
#         lat        lon   geometry_ref  ... confidence_activity  \
# 0  2.190811  99.053312  gadm_IDN.32_1  ...                high
# 1  2.190811  99.053312  gadm_IDN.32_1  ...                high
# ...

# %%
#check for duplicates
df.duplicated().sum()
# Out:
# 2500

# %%
#drop duplicates
df = df.drop_duplicates()

# %%
df.head()
# Out:
#    source_id     source_name  source_type iso3_country  \
# 0   21458521  Sumatera Utara          NaN          IDN
# 2   21458521  Sumatera Utara          NaN          IDN
# 4   21458521  Sumatera Utara          NaN          IDN
# 6   21458521  Sumatera Utara          NaN          IDN
# 8   21458521  Sumatera Utara          NaN          IDN
#
#   original_inventory_sector    source_start_time      source_end_time  \
# 0          rice-cultivation  2021-01-01 00:00:00  2021-12-31 00:00:00
# 2          rice-cultivation  2021-01-01 00:00:00  2021-12-31 00:00:00
# 4          rice-cultivation  2021-01-01 00:00:00  2021-12-31 00:00:00
# 6          rice-cultivation  2021-01-01 00:00:00  2021-12-31 00:00:00
# 8          rice-cultivation  2021-01-01 00:00:00  2021-12-31 00:00:00
#
#         lat        lon   geometry_ref  ... confidence_activity  \
# 0  2.190811  99.053312  gadm_IDN.32_1  ...                high
# 2  2.190811  99.053312  gadm_IDN.32_1  ...                high
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
##check the various source name
source_names_unique = df['iso3_country'].unique()
print(source_names_unique)
# Out:
# ['IDN' 'IND']
